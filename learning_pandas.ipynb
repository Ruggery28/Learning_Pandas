# %%
import pandas as pd
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)
df.info() #getting all the information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head() #method head shows the first 5 rows of the table (how much you want)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#We can use isnull and combine with sum to see how many rows are empty 
df.isnull().sum()           #it will show all collumns
df['Age'].isnull().sum()    #it will show only 'Age'
df.isnull().sum().sort_values(ascending=False) #can sort it False from the high to low
# Out:
# Cabin          687
# Age            177
# Embarked         2
# PassengerId      0
# Name             0
# Pclass           0
# Survived         0
# Sex              0
# Parch            0
# SibSp            0
# Fare             0
# Ticket           0
# dtype: int64

# %%
#To see the values that is missing
missing_values = df[df['Age'].isnull()]
missing_values.head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %%
#show only the collumns you want
df[['Age', 'Name']].head()
# Out:
#     Age                                               Name
# 0  22.0                            Braund, Mr. Owen Harris
# 1  38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2  26.0                             Heikkinen, Miss. Laina
# 3  35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4  35.0                           Allen, Mr. William Henry

# %%
#FILTERING WITH CONDITIONS
df[df['Age'] > 30].head(3) #filtering with one condition
df[(df['Age'] > 30) & (df['Sex'] == 'male')].head() #filtering with more than one conditions
# Out:
#     PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 4             5         0       3     Allen, Mr. William Henry  male  35.0
# 6             7         0       1      McCarthy, Mr. Timothy J  male  54.0
# 13           14         0       3  Andersson, Mr. Anders Johan  male  39.0
# 20           21         0       2         Fynney, Mr. Joseph J  male  35.0
# 21           22         1       2        Beesley, Mr. Lawrence  male  34.0
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 4       0      0  373450   8.0500   NaN        S
# 6       0      0   17463  51.8625   E46        S
# 13      1      5  347082  31.2750   NaN        S
# 20      0      0  239865  26.0000   NaN        S
# 21      0      0  248698  13.0000   D56        S

# %%
#Filtering text
df[df['Name'].str.contains('Mrs')].head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C
# 3      0    113803  53.1000  C123        S
# 8      2    347742  11.1333   NaN        S

# %%
#Droping rowns where is missing values
df.dropna(subset=['Age']).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Filling missing values - Replace missing values with a number, string, or calculation:
df['Age'] = df['Age'].fillna(df['Age'].median())  # median age
df['Cabin'] = df['Cabin'].fillna('Unknown')       # label missing cabins
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked
# 0      0         A/5 21171   7.2500  Unknown        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250  Unknown        S
# 3      0            113803  53.1000     C123        S
# ...

# %%
#Combination of all I have learned: Filling missing values, Renaming columns, changing types, sorting vales and groupby
df = (
    df.fillna({'Age': df['Age'].median(), 'Cabin': 'Unknown', 'Embarked': 'Unknown'})
    .rename(columns={'Pclass': 'PassengerClass', 'Fare': 'TicketFare'})
    .astype({'TicketFare': float})
    .sort_values(by=['PassengerClass', 'TicketFare'], ascending=[True, False])
    .groupby('PassengerClass').head(3) # keeps only top rows without grouping index
    [['PassengerClass', 'Name', 'Age', 'TicketFare', 'Cabin']]
    
)
df
# Out:
#      PassengerClass                                Name   Age  TicketFare  \
# 258               1                    Ward, Miss. Anna  35.0    512.3292
# 679               1  Cardeza, Mr. Thomas Drake Martinez  36.0    512.3292
# 737               1              Lesurer, Mr. Gustave J  35.0    512.3292
# 72                2                Hood, Mr. Ambrose Jr  21.0     73.5000
# 120               2         Hickman, Mr. Stanley George  21.0     73.5000
# 385               2           Davies, Mr. Charles Henry  18.0     73.5000
# 159               3          Sage, Master. Thomas Henry  28.0     69.5500
# 180               3        Sage, Miss. Constance Gladys  28.0     69.5500
# 201               3                 Sage, Mr. Frederick  28.0     69.5500
#
#            Cabin
# 258      Unknown
# 679  B51 B53 B55
# 737         B101
# 72       Unknown
# 120      Unknown
# 385      Unknown
# 159      Unknown
# 180      Unknown
# 201      Unknown

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# map numeric to labels (helps the legend)
df['Survived_label'] = df['Survived'].map({0: 'No', 1: 'Yes'})

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Sex', hue='Survived_label', palette={'No':'#4c72b0','Yes':'#dd8452'})
plt.title('Survival by Sex')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.legend(title='Survived')
plt.show()

# %%
#Age Distribuition by survival
plt.figure(figsize=(6,4))
sns.histplot(data=df, x='Age', hue='Survived', multiple='stack', palette='Set2')
plt.title('Age Distribution by Survival')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
#Survival by Passenger Class
plt.figure(figsize=(5,4))
sns.countplot(data=df, x='Pclass', hue='Survived', palette='Set2')
plt.title('Survival by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.show()
